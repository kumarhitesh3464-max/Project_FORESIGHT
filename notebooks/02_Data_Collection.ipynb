# %% [markdown]
# # Phase 2: Data Collection
#
# ## Objective
#
# The objective of this notebook is to collect and understand all datasets required for Project FORESIGHT.
#
# Tasks performed:
#
# - Import required libraries
# - Load datasets
# - Explore dataset dimensions
# - Inspect column names
# - Check data types
# - Display sample records

# %%
# Import Required Libraries

import pandas as pd
import numpy as np

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# # Load Datasets
#
# The project uses three available datasets:
#
# - sales_transaction.csv
# - sku_master.csv
# - inventory_snapshot.csv
#
# The calendar dataset will be generated later from the sales date column.

# %%
import pandas as pd

sales = pd.read_csv("../data/raw/sales_transactions.csv")

sku = pd.read_csv("../data/raw/sku_master.csv")

inventory = pd.read_csv("../data/raw/inventory_snapshot.csv")

print("Datasets Loaded Successfully")
# Out:
# Datasets Loaded Successfully

# %% [markdown]
# # Dataset Shapes
#
# Understanding the size of each dataset.

# %%
print("Sales Dataset :", sales.shape)

print("SKU Dataset :", sku.shape)

print("Inventory Dataset :", inventory.shape)
# Out:
# Sales Dataset : (9972038, 11)
# SKU Dataset : (5000, 7)
# Inventory Dataset : (21228, 6)

# %% [markdown]
# # Dataset Information
#
# Checking columns and data types.

# %%
print("Sales Dataset Info")

sales.info()
# Out:
# Sales Dataset Info
# <class 'pandas.DataFrame'>
# RangeIndex: 9972038 entries, 0 to 9972037
# Data columns (total 11 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          str
#  1   receipt_id    str
#  2   store_id      str
#  3   sku_id        str
#  4   customer_id   str
#  5   quantity      int64
#  6   unit_price    float64
#  7   total_value   float64
#  8   channel       str
#  9   discount_pct  float64
#  10  promo_id      str
# dtypes: float64(3), int64(1), str(7)
# memory usage: 1.3 GB

# %%
print("SKU Dataset Info")

sku.info()
# Out:
# SKU Dataset Info
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku_id       5000 non-null   str
#  1   sku_name     5000 non-null   str
#  2   category     5000 non-null   str
#  3   subcategory  5000 non-null   str
#  4   unit_price   5000 non-null   float64
#  5   cost_price   5000 non-null   float64
#  6   brand        5000 non-null   str
# dtypes: float64(2), str(5)
# memory usage: 629.9 KB

# %%
print("Inventory Dataset Info")

inventory.info()
# Out:
# Inventory Dataset Info
# <class 'pandas.DataFrame'>
# RangeIndex: 21228 entries, 0 to 21227
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   store_id           21228 non-null  str
#  1   sku_id             21228 non-null  str
#  2   stock_on_hand      21228 non-null  int64
#  3   reorder_point      21228 non-null  int64
#  4   safety_stock       21228 non-null  int64
#  5   last_restock_date  21228 non-null  str
# dtypes: int64(3), str(3)
# memory usage: 1.4 MB

# %% [markdown]
# # Column Names

# %%
print("Sales Columns")

print(sales.columns.tolist())

print("\nSKU Columns")

print(sku.columns.tolist())

print("\nInventory Columns")

print(inventory.columns.tolist())
# Out:
# Sales Columns
# ['date', 'receipt_id', 'store_id', 'sku_id', 'customer_id', 'quantity', 'unit_price', 'total_value', 'channel', 'discount_pct', 'promo_id']
#
# SKU Columns
# ['sku_id', 'sku_name', 'category', 'subcategory', 'unit_price', 'cost_price', 'brand']
#
# Inventory Columns
# ['store_id', 'sku_id', 'stock_on_hand', 'reorder_point', 'safety_stock', 'last_restock_date']

# %% [markdown]
# # Preview of Sales Dataset

# %%
sales.head()
# Out:
#          date    receipt_id store_id    sku_id customer_id  quantity  \
# 0  2025-04-02  RCPT00000001     ST16  SKU02498   CUST01410         1
# 1  2025-04-02  RCPT00000001     ST16  SKU04596   CUST01410         3
# 2  2022-04-24  RCPT00000002     ST15  SKU00078   CUST00134         1
# 3  2022-04-24  RCPT00000002     ST15  SKU00554   CUST00134         2
# 4  2024-09-22  RCPT00000003     ST20  SKU03727   CUST08826         1
#
#    unit_price  total_value   channel  discount_pct promo_id
# 0     2379.11      2379.11  In-Store           0.0      NaN
# 1      335.55      1006.65  In-Store           0.0      NaN
# 2      820.53       820.53    Online           0.0      NaN
# 3       88.32       176.64    Online           0.0      NaN
# 4     1660.93      1660.93    Online           0.0      NaN

# %% [markdown]
# # Preview of SKU Dataset

# %%
sku.head()
# Out:
#      sku_id                             sku_name             category  \
# 0  SKU00001             NutriPlus Cookware Large       Home & Kitchen
# 1  SKU00002          CrispKing Bread Family Pack       Dairy & Bakery
# 2  SKU00003               SoftTouch Notebooks 2L  Stationery & Office
# 3  SKU00004              SunriseFoods Eggs Large       Dairy & Bakery
# 4  SKU00005  SunriseFoods Pest Control Pack of 6            Home Care
#
#     subcategory  unit_price  cost_price         brand
# 0      Cookware      813.41      619.77     NutriPlus
# 1         Bread       70.38       49.57     CrispKing
# 2     Notebooks      151.28       83.67     SoftTouch
# 3          Eggs      233.64      156.32  SunriseFoods
# 4  Pest Control      138.50       83.46  SunriseFoods

# %% [markdown]
# # Preview of Inventory Dataset

# %%
inventory.head()
# Out:
#   store_id    sku_id  stock_on_hand  reorder_point  safety_stock  \
# 0     ST11  SKU02558            323             72            22
# 1     ST21  SKU01031            236             67            14
# 2     ST26  SKU02129            433             96            34
# 3     ST19  SKU02907            178             34            13
# 4     ST05  SKU01023            333             97            22
#
#   last_restock_date
# 0        2025-05-17
# 1        2025-06-17
# 2        2025-05-20
# 3        2025-08-03
# 4        2025-07-12

# %% [markdown]
# # Initial Observations
#
# At this stage:
#
# - All datasets have been successfully loaded.
# - Dataset dimensions have been verified.
# - Columns and data types have been inspected.
# - Sample records have been reviewed.
#
# The next step is Data Cleaning, where missing values, duplicates, invalid records, and incorrect data types will be handled.
