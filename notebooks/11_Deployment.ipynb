# %% [markdown]
# # Project FORESIGHT
#
# # Phase 8 : Deployment & Documentation
#
# ## Objective
#
# The objective of this notebook is to demonstrate the deployment process of Project FORESIGHT.
#
# This includes:
#
# - Project Structure
# - Environment Setup
# - Required Libraries
# - Running Streamlit Application
# - GitHub Repository
# - Streamlit Cloud Deployment
# - Deployment Verification
# - Final Application

# %% [markdown]
# # Project Folder Structure

# %%
from pathlib import Path

project = Path.cwd()

for item in sorted(project.iterdir()):
    print(item.name)
# Out:
# 01_Business_Understanding.ipynb
# 02_Data_Collection.ipynb
# 03_Data_Cleaning.ipynb
# 04_EDA.ipynb
# 05_Feature_Engineering.ipynb
# 06_Baseline_Model.ipynb
# 07_ML_Forecasting.ipynb
# 08_Model_Evaluation.ipynb
# 09_Risk_Scoring.ipynb
# 10_Streamlit_Dashboard.ipynb
# 11_Deployment.ipynb
# 12_Executive_Summary.ipynb

# %% [markdown]
# ## Required Libraries
#
# The project uses the following libraries:
#
# - pandas
# - numpy
# - scikit-learn
# - xgboost
# - lightgbm
# - prophet
# - plotly
# - streamlit
# - pillow
# - matplotlib
# - seaborn
# - joblib

# %%
print("Run the following command in Terminal:")

print()

print("streamlit run app.py")
# Out:
# Run the following command in Terminal:
#
# streamlit run app.py

# %% [markdown]
# # Local Deployment
#
# The dashboard was successfully executed on the local machine.
#
# Application includes:
#
# - Home Dashboard
# - Sales Analytics
# - Forecast Dashboard
# - Inventory Dashboard
# - Risk Dashboard
# - Product Details
# - Executive Summary

# %% [markdown]
# # GitHub Repository

# %% [markdown]
# https://github.com/kumarhitesh3464-max/Project_FORESIGHT

# %% [markdown]
# # Streamlit Cloud Deployment

# %% [markdown]
# Application
#
# https://project-foresight.streamlit.app

# %%
import os

print(os.listdir("../screenshots"))
# Out:
# ['executive.png', 'forecast.png', 'home.png', 'inventory.png', 'product.png', 'risk.png', 'sales.png']

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\HITESH\OneDrive\Desktop\Project_FORESIGHT\notebooks

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nScreenshots Folder Exists?")
print(os.path.exists("../screenshots"))

print("\nAbsolute Path:")
print(os.path.abspath("../screenshots"))
# Out:
# Current Folder:
# c:\Users\HITESH\OneDrive\Desktop\Project_FORESIGHT\notebooks
#
# Screenshots Folder Exists?
# True
#
# Absolute Path:
# c:\Users\HITESH\OneDrive\Desktop\Project_FORESIGHT\screenshots

# %%
import os
print(os.path.exists(os.path.abspath("../screenshots/risk.png")))
# Out:
# True

# %%
from IPython.display import Image, display

display(Image(filename=os.path.abspath("../screenshots/home.png")))

# %% [markdown]
# # Dashboard Screenshots
#
# ## 🏠 Home Dashboard
#
# ![](../screenshots/home.png)
#
# ---
#
# ## 📊 Sales Analytics
#
# ![](../screenshots/sales.png)
#
# ---
#
# ## 📈 Forecast Dashboard
#
# ![](../screenshots/forecast.png)
#
# ---
#
# ## 📦 Inventory Dashboard
#
# ![](../screenshots/inventory.png)
#
# ---
#
# ## ⚠️ Risk Dashboard
#
# ![](../screenshots/risk.png)
#
# ---
#
# ## 🔍 Product Details
#
# ![](../screenshots/product.png)
#
# ---
#
# ## 📋 Executive Summary
#
# ![](../screenshots/executive.png)

# %% [markdown]
# # Deployment Verification
#
# Deployment Checklist
#
# - Project Structure Verified
# - Requirements Installed
# - Streamlit Running Successfully
# - Dashboard Functional
# - Charts Loaded
# - Filters Working
# - Download Button Working
# - GitHub Repository Created
# - Streamlit Cloud Deployment Completed

# %% [markdown]
# # Conclusion
#
# Project FORESIGHT has been successfully deployed.
#
# The solution provides an end-to-end Retail Demand Forecasting and Inventory Risk Management Dashboard capable of supporting business decision-making through interactive visualizations and predictive analytics.
